# %% [markdown]
# Streams Library Log-book
# =========================
#
# This notebook keeps record of the intermediate computations made to generate some of the stream's footprints stored in the Streams Library

# %%
import numpy as np
import scipy
import pylab as plt
import galstreams
import myutils
import bovy_coords as bovyc
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %% [markdown]
# Alpheus
# -------

# %%
#Alpheus
dec=np.linspace(-69.,-45.,20)
ra = 32.116-0.00256*dec-0.00225*(dec**2)  #from Grillmair 2013
for raa,deca in zip(ra,dec):
 print '%.1f %+.1f 2. ' % (raa,deca)
# Out:
# 21.6 -69.0 2.
# 22.0 -67.7 2.
# 22.3 -66.5 2.
# 22.7 -65.2 2.
# 23.1 -63.9 2.
# 23.4 -62.7 2.
# 23.8 -61.4 2.
# 24.1 -60.2 2.
# 24.5 -58.9 2.
# 24.8 -57.6 2.
# 25.1 -56.4 2.
# 25.4 -55.1 2.
# 25.7 -53.8 2.
# 26.0 -52.6 2.
# 26.3 -51.3 2.
# 26.6 -50.1 2.
# 26.9 -48.8 2.
# 27.2 -47.5 2.
# 27.4 -46.3 2.
# 27.7 -45.0 2.

# %% [markdown]
# Hermus
# ------

# %%
#Hermus
dec=np.linspace(5.,+50.,200)
ra=241.571 + 1.37841*dec -0.148870*(dec**2) + 0.00589502*(dec**3) -1.03927E-4*(dec**4) + 7.28133E-7*(dec**5)
 #from Grillmair 2014
for raa,deca in zip(ra,dec):
 print '%.1f %+6.1f 18.5 ' % (raa,deca)
# Out:
# 245.4   +5.0 18.5
# 245.5   +5.2 18.5
# 245.5   +5.5 18.5
# 245.6   +5.7 18.5
# 245.6   +5.9 18.5
# 245.6   +6.1 18.5
# 245.7   +6.4 18.5
# 245.7   +6.6 18.5
# 245.7   +6.8 18.5
# 245.7   +7.0 18.5
# 245.7   +7.3 18.5
# 245.7   +7.5 18.5
# 245.7   +7.7 18.5
# 245.7   +7.9 18.5
# 245.7   +8.2 18.5
# 245.7   +8.4 18.5
# 245.6   +8.6 18.5
# 245.6   +8.8 18.5
# 245.6   +9.1 18.5
# 245.5   +9.3 18.5
# 245.5   +9.5 18.5
# 245.4   +9.7 18.5
# 245.4  +10.0 18.5
# 245.4  +10.2 18.5
# 245.3  +10.4 18.5
# 245.2  +10.7 18.5
# 245.2  +10.9 18.5
# 245.1  +11.1 18.5
# 245.1  +11.3 18.5
# 245.0  +11.6 18.5
# 244.9  +11.8 18.5
# 244.9  +12.0 18.5
# 244.8  +12.2 18.5
# 244.8  +12.5 18.5
# 244.7  +12.7 18.5
# 244.6  +12.9 18.5
# 244.5  +13.1 18.5
# 244.5  +13.4 18.5
# 244.4  +13.6 18.5
# 244.3  +13.8 18.5
# 244.3  +14.0 18.5
# 244.2  +14.3 18.5
# 244.1  +14.5 18.5
# 244.0  +14.7 18.5
# 244.0  +14.9 18.5
# 243.9  +15.2 18.5
# 243.8  +15.4 18.5
# 243.7  +15.6 18.5
# 243.7  +15.9 18.5
# 243.6  +16.1 18.5
# 243.5  +16.3 18.5
# 243.4  +16.5 18.5
# 243.4  +16.8 18.5
# 243.3  +17.0 18.5
# 243.2  +17.2 18.5
# 243.2  +17.4 18.5
# 243.1  +17.7 18.5
# 243.0  +17.9 18.5
# 243.0  +18.1 18.5
# 242.9  +18.3 18.5
# 242.8  +18.6 18.5
# 242.8  +18.8 18.5
# 242.7  +19.0 18.5
# 242.6  +19.2 18.5
# 242.6  +19.5 18.5
# 242.5  +19.7 18.5
# 242.5  +19.9 18.5
# 242.4  +20.2 18.5
# 242.4  +20.4 18.5
# 242.3  +20.6 18.5
# 242.3  +20.8 18.5
# 242.2  +21.1 18.5
# 242.2  +21.3 18.5
# 242.1  +21.5 18.5
# 242.1  +21.7 18.5
# 242.0  +22.0 18.5
# 242.0  +22.2 18.5
# 241.9  +22.4 18.5
# 241.9  +22.6 18.5
# 241.9  +22.9 18.5
# 241.8  +23.1 18.5
# 241.8  +23.3 18.5
# 241.8  +23.5 18.5
# 241.7  +23.8 18.5
# 241.7  +24.0 18.5
# 241.7  +24.2 18.5
# 241.7  +24.4 18.5
# 241.6  +24.7 18.5
# 241.6  +24.9 18.5
# 241.6  +25.1 18.5
# 241.6  +25.4 18.5
# 241.6  +25.6 18.5
# 241.6  +25.8 18.5
# 241.5  +26.0 18.5
# 241.5  +26.3 18.5
# 241.5  +26.5 18.5
# 241.5  +26.7 18.5
# 241.5  +26.9 18.5
# 241.5  +27.2 18.5
# 241.5  +27.4 18.5
# 241.5  +27.6 18.5
# 241.5  +27.8 18.5
# 241.5  +28.1 18.5
# 241.5  +28.3 18.5
# 241.5  +28.5 18.5
# 241.5  +28.7 18.5
# 241.5  +29.0 18.5
# 241.6  +29.2 18.5
# 241.6  +29.4 18.5
# 241.6  +29.6 18.5
# 241.6  +29.9 18.5
# 241.6  +30.1 18.5
# 241.6  +30.3 18.5
# 241.7  +30.6 18.5
# 241.7  +30.8 18.5
# 241.7  +31.0 18.5
# 241.8  +31.2 18.5
# 241.8  +31.5 18.5
# 241.8  +31.7 18.5
# 241.8  +31.9 18.5
# 241.9  +32.1 18.5
# 241.9  +32.4 18.5
# 242.0  +32.6 18.5
# 242.0  +32.8 18.5
# 242.0  +33.0 18.5
# 242.1  +33.3 18.5
# 242.1  +33.5 18.5
# 242.2  +33.7 18.5
# 242.2  +33.9 18.5
# 242.3  +34.2 18.5
# 242.3  +34.4 18.5
# 242.4  +34.6 18.5
# 242.4  +34.8 18.5
# 242.5  +35.1 18.5
# 242.6  +35.3 18.5
# 242.6  +35.5 18.5
# 242.7  +35.8 18.5
# 242.8  +36.0 18.5
# 242.8  +36.2 18.5
# 242.9  +36.4 18.5
# 243.0  +36.7 18.5
# 243.0  +36.9 18.5
# 243.1  +37.1 18.5
# 243.2  +37.3 18.5
# 243.3  +37.6 18.5
# 243.4  +37.8 18.5
# 243.5  +38.0 18.5
# 243.5  +38.2 18.5
# 243.6  +38.5 18.5
# 243.7  +38.7 18.5
# 243.8  +38.9 18.5
# 243.9  +39.1 18.5
# 244.0  +39.4 18.5
# 244.1  +39.6 18.5
# 244.2  +39.8 18.5
# 244.3  +40.1 18.5
# 244.4  +40.3 18.5
# 244.6  +40.5 18.5
# 244.7  +40.7 18.5
# 244.8  +41.0 18.5
# 244.9  +41.2 18.5
# 245.0  +41.4 18.5
# 245.2  +41.6 18.5
# 245.3  +41.9 18.5
# 245.4  +42.1 18.5
# 245.6  +42.3 18.5
# 245.7  +42.5 18.5
# 245.9  +42.8 18.5
# 246.0  +43.0 18.5
# 246.2  +43.2 18.5
# 246.3  +43.4 18.5
# 246.5  +43.7 18.5
# 246.6  +43.9 18.5
# 246.8  +44.1 18.5
# 247.0  +44.3 18.5
# 247.2  +44.6 18.5
# 247.3  +44.8 18.5
# 247.5  +45.0 18.5
# 247.7  +45.3 18.5
# 247.9  +45.5 18.5
# 248.1  +45.7 18.5
# 248.3  +45.9 18.5
# 248.6  +46.2 18.5
# 248.8  +46.4 18.5
# 249.0  +46.6 18.5
# 249.2  +46.8 18.5
# 249.5  +47.1 18.5
# 249.7  +47.3 18.5
# 250.0  +47.5 18.5
# 250.2  +47.7 18.5
# 250.5  +48.0 18.5
# 250.8  +48.2 18.5
# 251.0  +48.4 18.5
# 251.3  +48.6 18.5
# 251.6  +48.9 18.5
# 251.9  +49.1 18.5
# 252.2  +49.3 18.5
# 252.5  +49.5 18.5
# 252.9  +49.8 18.5
# 253.2  +50.0 18.5

# %% [markdown]
# Hyllus
# ------

# %%
#Hyllus
dec=np.linspace(11.,+34.,200)
ra=255.8150-0.78364*dec + 0.01532*dec**2
 #from Grillmair 2014
for raa,deca in zip(ra,dec):
 print '%.1f %+.1f 20. ' % (raa,deca)
# Out:
# 249.0 +11.0 20.
# 249.0 +11.1 20.
# 248.9 +11.2 20.
# 248.9 +11.3 20.
# 248.8 +11.5 20.
# 248.8 +11.6 20.
# 248.7 +11.7 20.
# 248.7 +11.8 20.
# 248.6 +11.9 20.
# 248.6 +12.0 20.
# 248.6 +12.2 20.
# 248.5 +12.3 20.
# 248.5 +12.4 20.
# 248.4 +12.5 20.
# 248.4 +12.6 20.
# 248.3 +12.7 20.
# 248.3 +12.8 20.
# 248.2 +13.0 20.
# 248.2 +13.1 20.
# 248.1 +13.2 20.
# 248.1 +13.3 20.
# 248.1 +13.4 20.
# 248.0 +13.5 20.
# 248.0 +13.7 20.
# 247.9 +13.8 20.
# 247.9 +13.9 20.
# 247.8 +14.0 20.
# 247.8 +14.1 20.
# 247.8 +14.2 20.
# 247.7 +14.4 20.
# 247.7 +14.5 20.
# 247.6 +14.6 20.
# 247.6 +14.7 20.
# 247.6 +14.8 20.
# 247.5 +14.9 20.
# 247.5 +15.0 20.
# 247.5 +15.2 20.
# 247.4 +15.3 20.
# 247.4 +15.4 20.
# 247.3 +15.5 20.
# 247.3 +15.6 20.
# 247.3 +15.7 20.
# 247.2 +15.9 20.
# 247.2 +16.0 20.
# 247.2 +16.1 20.
# 247.1 +16.2 20.
# 247.1 +16.3 20.
# 247.1 +16.4 20.
# 247.0 +16.5 20.
# 247.0 +16.7 20.
# 247.0 +16.8 20.
# 246.9 +16.9 20.
# 246.9 +17.0 20.
# 246.9 +17.1 20.
# 246.9 +17.2 20.
# 246.8 +17.4 20.
# 246.8 +17.5 20.
# 246.8 +17.6 20.
# 246.7 +17.7 20.
# 246.7 +17.8 20.
# 246.7 +17.9 20.
# 246.7 +18.1 20.
# 246.6 +18.2 20.
# 246.6 +18.3 20.
# 246.6 +18.4 20.
# 246.6 +18.5 20.
# 246.5 +18.6 20.
# 246.5 +18.7 20.
# 246.5 +18.9 20.
# 246.5 +19.0 20.
# 246.4 +19.1 20.
# 246.4 +19.2 20.
# 246.4 +19.3 20.
# 246.4 +19.4 20.
# 246.3 +19.6 20.
# 246.3 +19.7 20.
# 246.3 +19.8 20.
# 246.3 +19.9 20.
# 246.3 +20.0 20.
# 246.2 +20.1 20.
# 246.2 +20.2 20.
# 246.2 +20.4 20.
# 246.2 +20.5 20.
# 246.2 +20.6 20.
# 246.2 +20.7 20.
# 246.1 +20.8 20.
# 246.1 +20.9 20.
# 246.1 +21.1 20.
# 246.1 +21.2 20.
# 246.1 +21.3 20.
# 246.1 +21.4 20.
# 246.0 +21.5 20.
# 246.0 +21.6 20.
# 246.0 +21.7 20.
# 246.0 +21.9 20.
# 246.0 +22.0 20.
# 246.0 +22.1 20.
# 246.0 +22.2 20.
# 246.0 +22.3 20.
# 245.9 +22.4 20.
# 245.9 +22.6 20.
# 245.9 +22.7 20.
# 245.9 +22.8 20.
# 245.9 +22.9 20.
# 245.9 +23.0 20.
# 245.9 +23.1 20.
# 245.9 +23.3 20.
# 245.9 +23.4 20.
# 245.9 +23.5 20.
# 245.9 +23.6 20.
# 245.8 +23.7 20.
# 245.8 +23.8 20.
# 245.8 +23.9 20.
# 245.8 +24.1 20.
# 245.8 +24.2 20.
# 245.8 +24.3 20.
# 245.8 +24.4 20.
# 245.8 +24.5 20.
# 245.8 +24.6 20.
# 245.8 +24.8 20.
# 245.8 +24.9 20.
# 245.8 +25.0 20.
# 245.8 +25.1 20.
# 245.8 +25.2 20.
# 245.8 +25.3 20.
# 245.8 +25.4 20.
# 245.8 +25.6 20.
# 245.8 +25.7 20.
# 245.8 +25.8 20.
# 245.8 +25.9 20.
# 245.8 +26.0 20.
# 245.8 +26.1 20.
# 245.8 +26.3 20.
# 245.8 +26.4 20.
# 245.8 +26.5 20.
# 245.8 +26.6 20.
# 245.8 +26.7 20.
# 245.8 +26.8 20.
# 245.8 +26.9 20.
# 245.8 +27.1 20.
# 245.8 +27.2 20.
# 245.8 +27.3 20.
# 245.8 +27.4 20.
# 245.9 +27.5 20.
# 245.9 +27.6 20.
# 245.9 +27.8 20.
# 245.9 +27.9 20.
# 245.9 +28.0 20.
# 245.9 +28.1 20.
# 245.9 +28.2 20.
# 245.9 +28.3 20.
# 245.9 +28.5 20.
# 245.9 +28.6 20.
# 245.9 +28.7 20.
# 246.0 +28.8 20.
# 246.0 +28.9 20.
# 246.0 +29.0 20.
# 246.0 +29.1 20.
# 246.0 +29.3 20.
# 246.0 +29.4 20.
# 246.0 +29.5 20.
# 246.0 +29.6 20.
# 246.1 +29.7 20.
# 246.1 +29.8 20.
# 246.1 +30.0 20.
# 246.1 +30.1 20.
# 246.1 +30.2 20.
# 246.1 +30.3 20.
# 246.2 +30.4 20.
# 246.2 +30.5 20.
# 246.2 +30.6 20.
# 246.2 +30.8 20.
# 246.2 +30.9 20.
# 246.2 +31.0 20.
# 246.3 +31.1 20.
# 246.3 +31.2 20.
# 246.3 +31.3 20.
# 246.3 +31.5 20.
# 246.3 +31.6 20.
# 246.4 +31.7 20.
# 246.4 +31.8 20.
# 246.4 +31.9 20.
# 246.4 +32.0 20.
# 246.5 +32.2 20.
# 246.5 +32.3 20.
# 246.5 +32.4 20.
# 246.5 +32.5 20.
# 246.6 +32.6 20.
# 246.6 +32.7 20.
# 246.6 +32.8 20.
# 246.6 +33.0 20.
# 246.7 +33.1 20.
# 246.7 +33.2 20.
# 246.7 +33.3 20.
# 246.7 +33.4 20.
# 246.8 +33.5 20.
# 246.8 +33.7 20.
# 246.8 +33.8 20.
# 246.9 +33.9 20.
# 246.9 +34.0 20.

# %% [markdown]
# Orphan
# ------
#
# This is the southern extension of the Orphan stream, reported by Grillmair+ 2015 (ApJ 812, 1–5)

# %%
#Orphan extension, Grillmair
orphan_ext_delta=np.linspace(-18.,-38.,4)
orphan_ext_alpha=163.147-0.0896*orphan_ext_delta+0.00804*(orphan_ext_delta**2)
orph_l,orph_b=bovyc.radec_to_lb(orphan_ext_alpha,orphan_ext_delta,degree=True).T
for la,ba in zip(orph_l,orph_b):
 print '%.1f %+.1f -1. ' % (la,ba)
# Out:
# 271.4 +38.5 -1.
# 278.1 +33.8 -1.
# 284.4 +28.8 -1.
# 290.3 +23.4 -1.

# %% [markdown]
# Pal 15 and Eridanus
# -------------------
#
# Computed from position angle (PA) and length of the tails from Myeong+ 2017. For each cluster they report the PA and length *l* for the 'tail 1' and 'tail 2', the two tails coming out of the cluster.

# %%
#Pal 15
rac,decc=255.01,-0.5419
l1,PA1=59./60.,np.radians(340.)
l2,PA2=29./60.,np.radians(150.)

delta_ra1=l1*np.sin(PA1)/np.cos(np.radians(decc))
delta_dec1=l1*np.cos(PA1)
delta_ra2=l2*np.sin(PA2)/np.cos(np.radians(decc))
delta_dec2=l2*np.cos(PA2)

#print delta_ra1*np.cos(np.radians(decc)),delta_dec1
#print delta_ra2*np.cos(np.radians(decc)),delta_dec2

ra1,dec1=rac -delta_ra1,decc-delta_dec1
ra2,dec2=rac -delta_ra2,decc-delta_dec2

print ra1, dec1
print ra2,dec2
# Out:
# 255.346334851 -1.46593107711
# 254.768322524 -0.123321054838

# %%
#Eridanus
rac,decc=66.1854,-21.1869
l1,PA1=18./60.,np.radians(40.)
l2,PA2=11./60.,np.radians(220.)

delta_ra1=l1*np.sin(PA1)/np.cos(np.radians(decc))
delta_dec1=l1*np.cos(PA1)
delta_ra2=l1*np.sin(PA2)/np.cos(np.radians(decc))
delta_dec2=l1*np.cos(PA2)

#print delta_ra1*np.cos(np.radians(decc)),delta_dec1
#print delta_ra2*np.cos(np.radians(decc)),delta_dec2

ra1,dec1=rac -delta_ra1,decc-delta_dec1
ra2,dec2=rac -delta_ra2,decc-delta_dec2

print ra1, dec1
print ra2,dec2
# Out:
# 65.9785843122 -21.4167133329
# 66.3922156878 -20.9570866671

# %% [markdown]
# Murrumbidgee
# -------------

# %%
#Murrumbidgee, From Grillmair 2017b
dec=np.linspace(-65,+16.,1000)  
#dec range is not clear in G17's paper, the fiducial point is not included in the mentioned
#range -65<dec<-30.
#print bovyc.lb_to_radec(180.,-5.)
ra=367.893 -0.4647*dec -0.00862*dec**2 + 0.000118*dec**3 +1.2347e-6*dec**4 -1.13758e-7*dec**5
ra=ra % 360.

ll,bb=bovyc.radec_to_lb(ra,dec,degree=True).T

for raa,deca in zip(ra,dec):
 print '%6.1f %+6.1f 20. ' % (raa,deca)  
   

plt.plot(ra,dec,'ko')   
mur_l,mur_b=galstreams.gcutils.get_gc_for_pole(160.,+28.)
D=20.*np.ones_like(mur_l)
mur=galstreams.Footprint(mur_l,mur_b,'Murrumbidgee',Rhel=D,degree=True,cootype='gal')

plt.plot(mur.ra,mur.dec)

plt.xlim(0.,380.)
plt.ylim(-90,20.)
# Out:
#  123.3  -65.0 20.
#  122.5  -64.9 20.
#  121.8  -64.8 20.
#  121.0  -64.8 20.
#  120.3  -64.7 20.
#  119.6  -64.6 20.
#  118.8  -64.5 20.
#  118.1  -64.4 20.
#  117.4  -64.4 20.
#  116.6  -64.3 20.
#  115.9  -64.2 20.
#  115.2  -64.1 20.
#  114.5  -64.0 20.
#  113.8  -63.9 20.
#  113.1  -63.9 20.
#  112.4  -63.8 20.
#  111.7  -63.7 20.
#  111.0  -63.6 20.
#  110.3  -63.5 20.
#  109.6  -63.5 20.
#  108.9  -63.4 20.
#  108.3  -63.3 20.
#  107.6  -63.2 20.
#  106.9  -63.1 20.
#  106.2  -63.1 20.
#  105.6  -63.0 20.
#  104.9  -62.9 20.
#  104.3  -62.8 20.
#  103.6  -62.7 20.
#  103.0  -62.6 20.
#  102.3  -62.6 20.
#  101.7  -62.5 20.
#  101.0  -62.4 20.
#  100.4  -62.3 20.
#   99.8  -62.2 20.
#   99.2  -62.2 20.
#   98.5  -62.1 20.
#   97.9  -62.0 20.
#   97.3  -61.9 20.
#   96.7  -61.8 20.
#   96.1  -61.8 20.
#   95.5  -61.7 20.
#   94.9  -61.6 20.
#   94.3  -61.5 20.
#   93.7  -61.4 20.
#   93.1  -61.4 20.
#   92.5  -61.3 20.
#   91.9  -61.2 20.
#   91.3  -61.1 20.
#   90.7  -61.0 20.
#   90.2  -60.9 20.
#   89.6  -60.9 20.
#   89.0  -60.8 20.
#   88.5  -60.7 20.
#   87.9  -60.6 20.
#   87.4  -60.5 20.
#   86.8  -60.5 20.
#   86.2  -60.4 20.
#   85.7  -60.3 20.
#   85.2  -60.2 20.
#   84.6  -60.1 20.
#   84.1  -60.1 20.
#   83.5  -60.0 20.
#   83.0  -59.9 20.
#   82.5  -59.8 20.
#   82.0  -59.7 20.
#   81.4  -59.6 20.
#   80.9  -59.6 20.
#   80.4  -59.5 20.
#   79.9  -59.4 20.
#   79.4  -59.3 20.
#   78.9  -59.2 20.
#   78.4  -59.2 20.
#   77.9  -59.1 20.
#   77.4  -59.0 20.
#   76.9  -58.9 20.
#   76.4  -58.8 20.
#   75.9  -58.8 20.
#   75.4  -58.7 20.
#   74.9  -58.6 20.
#   74.4  -58.5 20.
#   74.0  -58.4 20.
#   73.5  -58.4 20.
#   73.0  -58.3 20.
#   72.5  -58.2 20.
#   72.1  -58.1 20.
#   71.6  -58.0 20.
#   71.2  -57.9 20.
#   70.7  -57.9 20.
#   70.2  -57.8 20.
#   69.8  -57.7 20.
#   69.3  -57.6 20.
#   68.9  -57.5 20.
#   68.5  -57.5 20.
#   68.0  -57.4 20.
#   67.6  -57.3 20.
#   67.1  -57.2 20.
#   66.7  -57.1 20.
#   66.3  -57.1 20.
#   65.9  -57.0 20.
#   65.4  -56.9 20.
#   65.0  -56.8 20.
#   64.6  -56.7 20.
#   64.2  -56.6 20.
#   63.8  -56.6 20.
#   63.4  -56.5 20.
#   63.0  -56.4 20.
#   62.5  -56.3 20.
#   62.1  -56.2 20.
#   61.7  -56.2 20.
#   61.3  -56.1 20.
#   61.0  -56.0 20.
#   60.6  -55.9 20.
#   60.2  -55.8 20.
#   59.8  -55.8 20.
#   59.4  -55.7 20.
#   59.0  -55.6 20.
#   58.6  -55.5 20.
#   58.3  -55.4 20.
#   57.9  -55.4 20.
#   57.5  -55.3 20.
#   57.1  -55.2 20.
#   56.8  -55.1 20.
#   56.4  -55.0 20.
#   56.1  -54.9 20.
#   55.7  -54.9 20.
#   55.3  -54.8 20.
#   55.0  -54.7 20.
#   54.6  -54.6 20.
#   54.3  -54.5 20.
#   53.9  -54.5 20.
#   53.6  -54.4 20.
#   53.2  -54.3 20.
#   52.9  -54.2 20.
#   52.6  -54.1 20.
#   52.2  -54.1 20.
#   51.9  -54.0 20.
#   51.6  -53.9 20.
#   51.2  -53.8 20.
#   50.9  -53.7 20.
#   50.6  -53.6 20.
#   50.3  -53.6 20.
#   49.9  -53.5 20.
#   49.6  -53.4 20.
#   49.3  -53.3 20.
#   49.0  -53.2 20.
#   48.7  -53.2 20.
#   48.4  -53.1 20.
#   48.1  -53.0 20.
#   47.8  -52.9 20.
#   47.4  -52.8 20.
#   47.1  -52.8 20.
#   46.8  -52.7 20.
#   46.6  -52.6 20.
#   46.3  -52.5 20.
#   46.0  -52.4 20.
#   45.7  -52.4 20.
#   45.4  -52.3 20.
#   45.1  -52.2 20.
#   44.8  -52.1 20.
#   44.5  -52.0 20.
#   44.2  -51.9 20.
#   44.0  -51.9 20.
#   43.7  -51.8 20.
#   43.4  -51.7 20.
#   43.1  -51.6 20.
#   42.9  -51.5 20.
#   42.6  -51.5 20.
#   42.3  -51.4 20.
#   42.1  -51.3 20.
#   41.8  -51.2 20.
#   41.6  -51.1 20.
#   41.3  -51.1 20.
#   41.0  -51.0 20.
#   40.8  -50.9 20.
#   40.5  -50.8 20.
#   40.3  -50.7 20.
#   40.0  -50.6 20.
#   39.8  -50.6 20.
#   39.5  -50.5 20.
#   39.3  -50.4 20.
#   39.0  -50.3 20.
#   38.8  -50.2 20.
#   38.6  -50.2 20.
#   38.3  -50.1 20.
#   38.1  -50.0 20.
#   37.9  -49.9 20.
#   37.6  -49.8 20.
#   37.4  -49.8 20.
#   37.2  -49.7 20.
#   36.9  -49.6 20.
#   36.7  -49.5 20.
#   36.5  -49.4 20.
#   36.3  -49.4 20.
#   36.1  -49.3 20.
#   35.8  -49.2 20.
#   35.6  -49.1 20.
#   35.4  -49.0 20.
#   35.2  -48.9 20.
#   35.0  -48.9 20.
#   34.8  -48.8 20.
#   34.6  -48.7 20.
#   34.4  -48.6 20.
#   34.2  -48.5 20.
#   34.0  -48.5 20.
#   33.7  -48.4 20.
#   33.5  -48.3 20.
#   33.4  -48.2 20.
#   33.2  -48.1 20.
#   33.0  -48.1 20.
#   32.8  -48.0 20.
#   32.6  -47.9 20.
#   32.4  -47.8 20.
#   32.2  -47.7 20.
#   32.0  -47.6 20.
#   31.8  -47.6 20.
#   31.6  -47.5 20.
#   31.5  -47.4 20.
#   31.3  -47.3 20.
#   31.1  -47.2 20.
#   30.9  -47.2 20.
#   30.7  -47.1 20.
#   30.6  -47.0 20.
#   30.4  -46.9 20.
#   30.2  -46.8 20.
#   30.0  -46.8 20.
#   29.9  -46.7 20.
#   29.7  -46.6 20.
#   29.5  -46.5 20.
#   29.4  -46.4 20.
#   29.2  -46.4 20.
#   29.0  -46.3 20.
#   28.9  -46.2 20.
#   28.7  -46.1 20.
#   28.6  -46.0 20.
#   28.4  -45.9 20.
#   28.2  -45.9 20.
#   28.1  -45.8 20.
#   27.9  -45.7 20.
#   27.8  -45.6 20.
#   27.6  -45.5 20.
#   27.5  -45.5 20.
#   27.3  -45.4 20.
#   27.2  -45.3 20.
#   27.0  -45.2 20.
#   26.9  -45.1 20.
#   26.7  -45.1 20.
#   26.6  -45.0 20.
#   26.5  -44.9 20.
#   26.3  -44.8 20.
#   26.2  -44.7 20.
#   26.0  -44.6 20.
#   25.9  -44.6 20.
#   25.8  -44.5 20.
#   25.6  -44.4 20.
#   25.5  -44.3 20.
#   25.4  -44.2 20.
#   25.2  -44.2 20.
#   25.1  -44.1 20.
#   25.0  -44.0 20.
#   24.9  -43.9 20.
#   24.7  -43.8 20.
#   24.6  -43.8 20.
#   24.5  -43.7 20.
#   24.4  -43.6 20.
#   24.2  -43.5 20.
#   24.1  -43.4 20.
#   24.0  -43.4 20.
#   23.9  -43.3 20.
#   23.8  -43.2 20.
#   23.7  -43.1 20.
#   23.5  -43.0 20.
#   23.4  -42.9 20.
#   23.3  -42.9 20.
#   23.2  -42.8 20.
#   23.1  -42.7 20.
#   23.0  -42.6 20.
#   22.9  -42.5 20.
#   22.8  -42.5 20.
#   22.7  -42.4 20.
#   22.6  -42.3 20.
#   22.4  -42.2 20.
#   22.3  -42.1 20.
#   22.2  -42.1 20.
#   22.1  -42.0 20.
#   22.0  -41.9 20.
#   21.9  -41.8 20.
#   21.8  -41.7 20.
#   21.7  -41.6 20.
#   21.6  -41.6 20.
#   21.5  -41.5 20.
#   21.5  -41.4 20.
#   21.4  -41.3 20.
#   21.3  -41.2 20.
#   21.2  -41.2 20.
#   21.1  -41.1 20.
#   21.0  -41.0 20.
#   20.9  -40.9 20.
#   20.8  -40.8 20.
#   20.7  -40.8 20.
#   20.6  -40.7 20.
#   20.6  -40.6 20.
#   20.5  -40.5 20.
#   20.4  -40.4 20.
#   20.3  -40.4 20.
#   20.2  -40.3 20.
#   20.1  -40.2 20.
#   20.1  -40.1 20.
#   20.0  -40.0 20.
#   19.9  -39.9 20.
#   19.8  -39.9 20.
#   19.7  -39.8 20.
#   19.7  -39.7 20.
#   19.6  -39.6 20.
#   19.5  -39.5 20.
#   19.4  -39.5 20.
#   19.4  -39.4 20.
#   19.3  -39.3 20.
#   19.2  -39.2 20.
#   19.1  -39.1 20.
#   19.1  -39.1 20.
#   19.0  -39.0 20.
#   18.9  -38.9 20.
#   18.9  -38.8 20.
#   18.8  -38.7 20.
#   18.7  -38.6 20.
#   18.7  -38.6 20.
#   18.6  -38.5 20.
#   18.5  -38.4 20.
#   18.5  -38.3 20.
#   18.4  -38.2 20.
#   18.3  -38.2 20.
#   18.3  -38.1 20.
#   18.2  -38.0 20.
#   18.2  -37.9 20.
#   18.1  -37.8 20.
#   18.0  -37.8 20.
#   18.0  -37.7 20.
#   17.9  -37.6 20.
#   17.9  -37.5 20.
#   17.8  -37.4 20.
#   17.7  -37.4 20.
#   17.7  -37.3 20.
#   17.6  -37.2 20.
#   17.6  -37.1 20.
#   17.5  -37.0 20.
#   17.5  -36.9 20.
#   17.4  -36.9 20.
#   17.4  -36.8 20.
#   17.3  -36.7 20.
#   17.3  -36.6 20.
#   17.2  -36.5 20.
#   17.2  -36.5 20.
#   17.1  -36.4 20.
#   17.1  -36.3 20.
#   17.0  -36.2 20.
#   17.0  -36.1 20.
#   16.9  -36.1 20.
#   16.9  -36.0 20.
#   16.8  -35.9 20.
#   16.8  -35.8 20.
#   16.7  -35.7 20.
#   16.7  -35.6 20.
#   16.7  -35.6 20.
#   16.6  -35.5 20.
#   16.6  -35.4 20.
#   16.5  -35.3 20.
#   16.5  -35.2 20.
#   16.4  -35.2 20.
#   16.4  -35.1 20.
#   16.4  -35.0 20.
#   16.3  -34.9 20.
#   16.3  -34.8 20.
#   16.2  -34.8 20.
#   16.2  -34.7 20.
#   16.2  -34.6 20.
#   16.1  -34.5 20.
#   16.1  -34.4 20.
#   16.1  -34.4 20.
#   16.0  -34.3 20.
#   16.0  -34.2 20.
#   16.0  -34.1 20.
#   15.9  -34.0 20.
#   15.9  -33.9 20.
#   15.9  -33.9 20.
#   15.8  -33.8 20.
#   15.8  -33.7 20.
#   15.8  -33.6 20.
#   15.7  -33.5 20.
#   15.7  -33.5 20.
#   15.7  -33.4 20.
#   15.6  -33.3 20.
#   15.6  -33.2 20.
#   15.6  -33.1 20.
#   15.5  -33.1 20.
#   15.5  -33.0 20.
#   15.5  -32.9 20.
#   15.4  -32.8 20.
#   15.4  -32.7 20.
#   15.4  -32.6 20.
#   15.4  -32.6 20.
#   15.3  -32.5 20.
#   15.3  -32.4 20.
#   15.3  -32.3 20.
#   15.3  -32.2 20.
#   15.2  -32.2 20.
#   15.2  -32.1 20.
#   15.2  -32.0 20.
#   15.2  -31.9 20.
#   15.1  -31.8 20.
#   15.1  -31.8 20.
#   15.1  -31.7 20.
#   15.1  -31.6 20.
#   15.0  -31.5 20.
#   15.0  -31.4 20.
#   15.0  -31.4 20.
#   15.0  -31.3 20.
#   14.9  -31.2 20.
#   14.9  -31.1 20.
#   14.9  -31.0 20.
#   14.9  -30.9 20.
#   14.9  -30.9 20.
#   14.8  -30.8 20.
#   14.8  -30.7 20.
#   14.8  -30.6 20.
#   14.8  -30.5 20.
#   14.8  -30.5 20.
#   14.7  -30.4 20.
#   14.7  -30.3 20.
#   14.7  -30.2 20.
#   14.7  -30.1 20.
#   14.7  -30.1 20.
#   14.6  -30.0 20.
#   14.6  -29.9 20.
#   14.6  -29.8 20.
#   14.6  -29.7 20.
#   14.6  -29.6 20.
#   14.6  -29.6 20.
#   14.5  -29.5 20.
#   14.5  -29.4 20.
#   14.5  -29.3 20.
#   14.5  -29.2 20.
#   14.5  -29.2 20.
#   14.5  -29.1 20.
#   14.4  -29.0 20.
#   14.4  -28.9 20.
#   14.4  -28.8 20.
#   14.4  -28.8 20.
#   14.4  -28.7 20.
#   14.4  -28.6 20.
#   14.4  -28.5 20.
#   14.3  -28.4 20.
#   14.3  -28.4 20.
#   14.3  -28.3 20.
#   14.3  -28.2 20.
#   14.3  -28.1 20.
#   14.3  -28.0 20.
#   14.3  -27.9 20.
#   14.3  -27.9 20.
#   14.2  -27.8 20.
#   14.2  -27.7 20.
#   14.2  -27.6 20.
#   14.2  -27.5 20.
#   14.2  -27.5 20.
#   14.2  -27.4 20.
#   14.2  -27.3 20.
#   14.2  -27.2 20.
#   14.1  -27.1 20.
#   14.1  -27.1 20.
#   14.1  -27.0 20.
#   14.1  -26.9 20.
#   14.1  -26.8 20.
#   14.1  -26.7 20.
#   14.1  -26.6 20.
#   14.1  -26.6 20.
#   14.1  -26.5 20.
#   14.0  -26.4 20.
#   14.0  -26.3 20.
#   14.0  -26.2 20.
#   14.0  -26.2 20.
#   14.0  -26.1 20.
#   14.0  -26.0 20.
#   14.0  -25.9 20.
#   14.0  -25.8 20.
#   14.0  -25.8 20.
#   14.0  -25.7 20.
#   13.9  -25.6 20.
#   13.9  -25.5 20.
#   13.9  -25.4 20.
#   13.9  -25.4 20.
#   13.9  -25.3 20.
#   13.9  -25.2 20.
#   13.9  -25.1 20.
#   13.9  -25.0 20.
#   13.9  -24.9 20.
#   13.9  -24.9 20.
#   13.8  -24.8 20.
#   13.8  -24.7 20.
#   13.8  -24.6 20.
#   13.8  -24.5 20.
#   13.8  -24.5 20.
#   13.8  -24.4 20.
#   13.8  -24.3 20.
#   13.8  -24.2 20.
#   13.8  -24.1 20.
#   13.8  -24.1 20.
#   13.8  -24.0 20.
#   13.8  -23.9 20.
#   13.7  -23.8 20.
#   13.7  -23.7 20.
#   13.7  -23.6 20.
#   13.7  -23.6 20.
#   13.7  -23.5 20.
#   13.7  -23.4 20.
#   13.7  -23.3 20.
#   13.7  -23.2 20.
#   13.7  -23.2 20.
#   13.7  -23.1 20.
#   13.7  -23.0 20.
#   13.7  -22.9 20.
#   13.6  -22.8 20.
#   13.6  -22.8 20.
#   13.6  -22.7 20.
#   13.6  -22.6 20.
#   13.6  -22.5 20.
#   13.6  -22.4 20.
#   13.6  -22.4 20.
#   13.6  -22.3 20.
#   13.6  -22.2 20.
#   13.6  -22.1 20.
#   13.6  -22.0 20.
#   13.6  -21.9 20.
#   13.5  -21.9 20.
#   13.5  -21.8 20.
#   13.5  -21.7 20.
#   13.5  -21.6 20.
#   13.5  -21.5 20.
#   13.5  -21.5 20.
#   13.5  -21.4 20.
#   13.5  -21.3 20.
#   13.5  -21.2 20.
#   13.5  -21.1 20.
#   13.5  -21.1 20.
#   13.5  -21.0 20.
#   13.5  -20.9 20.
#   13.4  -20.8 20.
#   13.4  -20.7 20.
#   13.4  -20.6 20.
#   13.4  -20.6 20.
#   13.4  -20.5 20.
#   13.4  -20.4 20.
#   13.4  -20.3 20.
#   13.4  -20.2 20.
#   13.4  -20.2 20.
#   13.4  -20.1 20.
#   13.4  -20.0 20.
#   13.3  -19.9 20.
#   13.3  -19.8 20.
#   13.3  -19.8 20.
#   13.3  -19.7 20.
#   13.3  -19.6 20.
#   13.3  -19.5 20.
#   13.3  -19.4 20.
#   13.3  -19.4 20.
#   13.3  -19.3 20.
#   13.3  -19.2 20.
#   13.3  -19.1 20.
#   13.2  -19.0 20.
#   13.2  -18.9 20.
#   13.2  -18.9 20.
#   13.2  -18.8 20.
#   13.2  -18.7 20.
#   13.2  -18.6 20.
#   13.2  -18.5 20.
#   13.2  -18.5 20.
#   13.2  -18.4 20.
#   13.2  -18.3 20.
#   13.1  -18.2 20.
#   13.1  -18.1 20.
#   13.1  -18.1 20.
#   13.1  -18.0 20.
#   13.1  -17.9 20.
#   13.1  -17.8 20.
#   13.1  -17.7 20.
#   13.1  -17.6 20.
#   13.1  -17.6 20.
#   13.1  -17.5 20.
#   13.0  -17.4 20.
#   13.0  -17.3 20.
#   13.0  -17.2 20.
#   13.0  -17.2 20.
#   13.0  -17.1 20.
#   13.0  -17.0 20.
#   13.0  -16.9 20.
#   13.0  -16.8 20.
#   13.0  -16.8 20.
#   12.9  -16.7 20.
#   12.9  -16.6 20.
#   12.9  -16.5 20.
#   12.9  -16.4 20.
#   12.9  -16.4 20.
#   12.9  -16.3 20.
#   12.9  -16.2 20.
#   12.9  -16.1 20.
#   12.8  -16.0 20.
#   12.8  -15.9 20.
#   12.8  -15.9 20.
#   12.8  -15.8 20.
#   12.8  -15.7 20.
#   12.8  -15.6 20.
#   12.8  -15.5 20.
#   12.8  -15.5 20.
#   12.7  -15.4 20.
#   12.7  -15.3 20.
#   12.7  -15.2 20.
#   12.7  -15.1 20.
#   12.7  -15.1 20.
#   12.7  -15.0 20.
#   12.7  -14.9 20.
#   12.6  -14.8 20.
#   12.6  -14.7 20.
#   12.6  -14.6 20.
#   12.6  -14.6 20.
#   12.6  -14.5 20.
#   12.6  -14.4 20.
#   12.6  -14.3 20.
#   12.5  -14.2 20.
#   12.5  -14.2 20.
#   12.5  -14.1 20.
#   12.5  -14.0 20.
#   12.5  -13.9 20.
#   12.5  -13.8 20.
#   12.4  -13.8 20.
#   12.4  -13.7 20.
#   12.4  -13.6 20.
#   12.4  -13.5 20.
#   12.4  -13.4 20.
#   12.4  -13.4 20.
#   12.4  -13.3 20.
#   12.3  -13.2 20.
#   12.3  -13.1 20.
#   12.3  -13.0 20.
#   12.3  -12.9 20.
#   12.3  -12.9 20.
#   12.3  -12.8 20.
#   12.2  -12.7 20.
#   12.2  -12.6 20.
#   12.2  -12.5 20.
#   12.2  -12.5 20.
#   12.2  -12.4 20.
#   12.1  -12.3 20.
#   12.1  -12.2 20.
#   12.1  -12.1 20.
#   12.1  -12.1 20.
#   12.1  -12.0 20.
#   12.1  -11.9 20.
#   12.0  -11.8 20.
#   12.0  -11.7 20.
#   12.0  -11.6 20.
#   12.0  -11.6 20.
#   12.0  -11.5 20.
#   11.9  -11.4 20.
#   11.9  -11.3 20.
#   11.9  -11.2 20.
#   11.9  -11.2 20.
#   11.9  -11.1 20.
#   11.8  -11.0 20.
#   11.8  -10.9 20.
#   11.8  -10.8 20.
#   11.8  -10.8 20.
#   11.8  -10.7 20.
#   11.7  -10.6 20.
#   11.7  -10.5 20.
#   11.7  -10.4 20.
#   11.7  -10.4 20.
#   11.7  -10.3 20.
#   11.6  -10.2 20.
#   11.6  -10.1 20.
#   11.6  -10.0 20.
#   11.6   -9.9 20.
#   11.5   -9.9 20.
#   11.5   -9.8 20.
#   11.5   -9.7 20.
#   11.5   -9.6 20.
#   11.5   -9.5 20.
#   11.4   -9.5 20.
#   11.4   -9.4 20.
#   11.4   -9.3 20.
#   11.4   -9.2 20.
#   11.3   -9.1 20.
#   11.3   -9.1 20.
#   11.3   -9.0 20.
#   11.3   -8.9 20.
#   11.3   -8.8 20.
#   11.2   -8.7 20.
#   11.2   -8.6 20.
#   11.2   -8.6 20.
#   11.2   -8.5 20.
#   11.1   -8.4 20.
#   11.1   -8.3 20.
#   11.1   -8.2 20.
#   11.1   -8.2 20.
#   11.0   -8.1 20.
#   11.0   -8.0 20.
#   11.0   -7.9 20.
#   11.0   -7.8 20.
#   10.9   -7.8 20.
#   10.9   -7.7 20.
#   10.9   -7.6 20.
#   10.9   -7.5 20.
#   10.8   -7.4 20.
#   10.8   -7.4 20.
#   10.8   -7.3 20.
#   10.7   -7.2 20.
#   10.7   -7.1 20.
#   10.7   -7.0 20.
#   10.7   -6.9 20.
#   10.6   -6.9 20.
#   10.6   -6.8 20.
#   10.6   -6.7 20.
#   10.6   -6.6 20.
#   10.5   -6.5 20.
#   10.5   -6.5 20.
#   10.5   -6.4 20.
#   10.5   -6.3 20.
#   10.4   -6.2 20.
#   10.4   -6.1 20.
#   10.4   -6.1 20.
#   10.3   -6.0 20.
#   10.3   -5.9 20.
#   10.3   -5.8 20.
#   10.3   -5.7 20.
#   10.2   -5.6 20.
#   10.2   -5.6 20.
#   10.2   -5.5 20.
#   10.1   -5.4 20.
#   10.1   -5.3 20.
#   10.1   -5.2 20.
#   10.0   -5.2 20.
#   10.0   -5.1 20.
#   10.0   -5.0 20.
#   10.0   -4.9 20.
#    9.9   -4.8 20.
#    9.9   -4.8 20.
#    9.9   -4.7 20.
#    9.8   -4.6 20.
#    9.8   -4.5 20.
#    9.8   -4.4 20.
#    9.7   -4.4 20.
#    9.7   -4.3 20.
#    9.7   -4.2 20.
#    9.6   -4.1 20.
#    9.6   -4.0 20.
#    9.6   -3.9 20.
#    9.6   -3.9 20.
#    9.5   -3.8 20.
#    9.5   -3.7 20.
#    9.5   -3.6 20.
#    9.4   -3.5 20.
#    9.4   -3.5 20.
#    9.4   -3.4 20.
#    9.3   -3.3 20.
#    9.3   -3.2 20.
#    9.3   -3.1 20.
#    9.2   -3.1 20.
#    9.2   -3.0 20.
#    9.2   -2.9 20.
#    9.1   -2.8 20.
#    9.1   -2.7 20.
#    9.1   -2.6 20.
#    9.0   -2.6 20.
#    9.0   -2.5 20.
#    9.0   -2.4 20.
#    8.9   -2.3 20.
#    8.9   -2.2 20.
#    8.9   -2.2 20.
#    8.8   -2.1 20.
#    8.8   -2.0 20.
#    8.8   -1.9 20.
#    8.7   -1.8 20.
#    8.7   -1.8 20.
#    8.6   -1.7 20.
#    8.6   -1.6 20.
#    8.6   -1.5 20.
#    8.5   -1.4 20.
#    8.5   -1.4 20.
#    8.5   -1.3 20.
#    8.4   -1.2 20.
#    8.4   -1.1 20.
#    8.4   -1.0 20.
#    8.3   -0.9 20.
#    8.3   -0.9 20.
#    8.3   -0.8 20.
#    8.2   -0.7 20.
#    8.2   -0.6 20.
#    8.1   -0.5 20.
#    8.1   -0.5 20.
#    8.1   -0.4 20.
#    8.0   -0.3 20.
#    8.0   -0.2 20.
#    8.0   -0.1 20.
#    7.9   -0.1 20.
#    7.9   +0.0 20.
#    7.8   +0.1 20.
#    7.8   +0.2 20.
#    7.8   +0.3 20.
#    7.7   +0.4 20.
#    7.7   +0.4 20.
#    7.7   +0.5 20.
#    7.6   +0.6 20.
#    7.6   +0.7 20.
#    7.5   +0.8 20.
#    7.5   +0.8 20.
#    7.5   +0.9 20.
#    7.4   +1.0 20.
#    7.4   +1.1 20.
#    7.3   +1.2 20.
#    7.3   +1.2 20.
#    7.3   +1.3 20.
#    7.2   +1.4 20.
#    7.2   +1.5 20.
#    7.1   +1.6 20.
#    7.1   +1.6 20.
#    7.1   +1.7 20.
#    7.0   +1.8 20.
#    7.0   +1.9 20.
#    6.9   +2.0 20.
#    6.9   +2.1 20.
#    6.9   +2.1 20.
#    6.8   +2.2 20.
#    6.8   +2.3 20.
#    6.7   +2.4 20.
#    6.7   +2.5 20.
#    6.7   +2.5 20.
#    6.6   +2.6 20.
#    6.6   +2.7 20.
#    6.5   +2.8 20.
#    6.5   +2.9 20.
#    6.5   +2.9 20.
#    6.4   +3.0 20.
#    6.4   +3.1 20.
#    6.3   +3.2 20.
#    6.3   +3.3 20.
#    6.2   +3.4 20.
#    6.2   +3.4 20.
#    6.2   +3.5 20.
#    6.1   +3.6 20.
#    6.1   +3.7 20.
#    6.0   +3.8 20.
#    6.0   +3.8 20.
#    5.9   +3.9 20.
#    5.9   +4.0 20.
#    5.9   +4.1 20.
#    5.8   +4.2 20.
#    5.8   +4.2 20.
#    5.7   +4.3 20.
#    5.7   +4.4 20.
#    5.6   +4.5 20.
#    5.6   +4.6 20.
#    5.6   +4.6 20.
#    5.5   +4.7 20.
#    5.5   +4.8 20.
#    5.4   +4.9 20.
#    5.4   +5.0 20.
#    5.3   +5.1 20.
#    5.3   +5.1 20.
#    5.3   +5.2 20.
#    5.2   +5.3 20.
#    5.2   +5.4 20.
#    5.1   +5.5 20.
#    5.1   +5.5 20.
#    5.0   +5.6 20.
#    5.0   +5.7 20.
#    4.9   +5.8 20.
#    4.9   +5.9 20.
#    4.9   +5.9 20.
#    4.8   +6.0 20.
#    4.8   +6.1 20.
#    4.7   +6.2 20.
#    4.7   +6.3 20.
#    4.6   +6.4 20.
#    4.6   +6.4 20.
#    4.5   +6.5 20.
#    4.5   +6.6 20.
#    4.4   +6.7 20.
#    4.4   +6.8 20.
#    4.4   +6.8 20.
#    4.3   +6.9 20.
#    4.3   +7.0 20.
#    4.2   +7.1 20.
#    4.2   +7.2 20.
#    4.1   +7.2 20.
#    4.1   +7.3 20.
#    4.0   +7.4 20.
#    4.0   +7.5 20.
#    3.9   +7.6 20.
#    3.9   +7.6 20.
#    3.8   +7.7 20.
#    3.8   +7.8 20.
#    3.7   +7.9 20.
#    3.7   +8.0 20.
#    3.7   +8.1 20.
#    3.6   +8.1 20.
#    3.6   +8.2 20.
#    3.5   +8.3 20.
#    3.5   +8.4 20.
#    3.4   +8.5 20.
#    3.4   +8.5 20.
#    3.3   +8.6 20.
#    3.3   +8.7 20.
#    3.2   +8.8 20.
#    3.2   +8.9 20.
#    3.1   +8.9 20.
#    3.1   +9.0 20.
#    3.0   +9.1 20.
#    3.0   +9.2 20.
#    2.9   +9.3 20.
#    2.9   +9.4 20.
#    2.8   +9.4 20.
#    2.8   +9.5 20.
#    2.7   +9.6 20.
#    2.7   +9.7 20.
#    2.6   +9.8 20.
#    2.6   +9.8 20.
#    2.6   +9.9 20.
#    2.5  +10.0 20.
#    2.5  +10.1 20.
#    2.4  +10.2 20.
#    2.4  +10.2 20.
#    2.3  +10.3 20.
#    2.3  +10.4 20.
#    2.2  +10.5 20.
#    2.2  +10.6 20.
#    2.1  +10.6 20.
#    2.1  +10.7 20.
#    2.0  +10.8 20.
#    2.0  +10.9 20.
#    1.9  +11.0 20.
#    1.9  +11.1 20.
#    1.8  +11.1 20.
#    1.8  +11.2 20.
#    1.7  +11.3 20.
#    1.7  +11.4 20.
#    1.6  +11.5 20.
#    1.6  +11.5 20.
#    1.5  +11.6 20.
#    1.5  +11.7 20.
#    1.4  +11.8 20.
#    1.4  +11.9 20.
#    1.3  +11.9 20.
#    1.3  +12.0 20.
#    1.2  +12.1 20.
#    1.2  +12.2 20.
#    1.1  +12.3 20.
#    1.1  +12.4 20.
#    1.0  +12.4 20.
#    1.0  +12.5 20.
#    0.9  +12.6 20.
#    0.9  +12.7 20.
#    0.8  +12.8 20.
#    0.8  +12.8 20.
#    0.7  +12.9 20.
#    0.6  +13.0 20.
#    0.6  +13.1 20.
#    0.5  +13.2 20.
#    0.5  +13.2 20.
#    0.4  +13.3 20.
#    0.4  +13.4 20.
#    0.3  +13.5 20.
#    0.3  +13.6 20.
#    0.2  +13.6 20.
#    0.2  +13.7 20.
#    0.1  +13.8 20.
#    0.1  +13.9 20.
#    0.0  +14.0 20.
#  360.0  +14.1 20.
#  359.9  +14.1 20.
#  359.9  +14.2 20.
#  359.8  +14.3 20.
#  359.8  +14.4 20.
#  359.7  +14.5 20.
#  359.7  +14.5 20.
#  359.6  +14.6 20.
#  359.6  +14.7 20.
#  359.5  +14.8 20.
#  359.4  +14.9 20.
#  359.4  +14.9 20.
#  359.3  +15.0 20.
#  359.3  +15.1 20.
#  359.2  +15.2 20.
#  359.2  +15.3 20.
#  359.1  +15.4 20.
#  359.1  +15.4 20.
#  359.0  +15.5 20.
#  359.0  +15.6 20.
#  358.9  +15.7 20.
#  358.9  +15.8 20.
#  358.8  +15.8 20.
#  358.8  +15.9 20.
#  358.7  +16.0 20.
# (-90, 20.0)

# %% [markdown]
# Molonglo
# --------

# %%
#Molonglo, From Grillmair 2017b
dec=np.linspace(-24.5,-12.,30)
ra=345.017 - 0.5843*dec + 0.0182*dec**2
ra=ra % 360.
for raa,deca in zip(ra,dec):
 print '%.1f %+.1f 20. ' % (raa,deca)   
    
mur_l,mur_b=galstreams.gcutils.get_gc_for_pole(193.,+22.)
D=20.*np.ones_like(mur_l)
mur=galstreams.Footprint(mur_l,mur_b,'Monlonglo',Rhel=D,degree=True,cootype='gal')    
plt.plot(ra,dec,'ko')   
plt.plot(mur.ra,mur.dec)
plt.xlim(0.,380.)
plt.ylim(-90,0.)
# Out:
# 10.3 -24.5 20.
# 9.6 -24.1 20.
# 9.0 -23.6 20.
# 8.4 -23.2 20.
# 7.8 -22.8 20.
# 7.2 -22.3 20.
# 6.6 -21.9 20.
# 6.0 -21.5 20.
# 5.4 -21.1 20.
# 4.8 -20.6 20.
# 4.2 -20.2 20.
# 3.7 -19.8 20.
# 3.1 -19.3 20.
# 2.6 -18.9 20.
# 2.0 -18.5 20.
# 1.5 -18.0 20.
# 0.9 -17.6 20.
# 0.4 -17.2 20.
# 359.9 -16.7 20.
# 359.4 -16.3 20.
# 358.9 -15.9 20.
# 358.4 -15.4 20.
# 357.9 -15.0 20.
# 357.4 -14.6 20.
# 356.9 -14.2 20.
# 356.5 -13.7 20.
# 356.0 -13.3 20.
# 355.5 -12.9 20.
# 355.1 -12.4 20.
# 354.6 -12.0 20.
# (-90, 0.0)

# %% [markdown]
# Orinoco
# --------

# %%
ra = np.linspace(0.,360.,1000)
dec = -25.5146 + 0.1672*ra -0.003827*ra**2 -0.0002835*ra**3 -5.3133e-6*ra**4
ra,dec=ra[np.abs(dec)<=90],dec[np.abs(dec)<=90]

ll,bb=bovyc.radec_to_lb(ra,dec,degree=True).T
maskb=(-62.<bb) & (bb<-48.)  #These are the limits quoted by G17b for the eastern part of Orinoco
ll,bb=ll[maskb],bb[maskb]

ras,decc=bovyc.lb_to_radec(ll,bb,degree=True).T

plt.plot(ll,bb,'bo')
plt.plot(ra,dec,'k.')
plt.plot(ras,decc,'ro')

for raa,deca in zip(ras,decc):
 print '%.1f %+.1f 20. ' % (raa,deca)
# Out:
# 36.8 -48.3 20.
# 37.1 -49.2 20.
# 37.5 -50.0 20.
# 37.8 -50.9 20.
# 38.2 -51.8 20.
# 38.6 -52.8 20.
# 38.9 -53.7 20.
# 39.3 -54.7 20.
# 39.6 -55.7 20.
# 40.0 -56.7 20.
# 40.4 -57.7 20.
# 40.7 -58.8 20.
# 41.1 -59.9 20.
# 41.4 -61.0 20.
# 41.8 -62.1 20.
# 42.2 -63.3 20.
# 42.5 -64.5 20.

# %% [markdown]
# Kwando
# -------

# %%
ras = np.linspace(19.,31.,30)
decs = -7.817 -2.354*ras +0.1202*ras**2 -0.00215*ras**3 

#st_l,st_b=galstreams.gcutils.get_gc_for_pole(237.,+13.)
#st=galstreams.Footprint(st_l,st_b,'Kwando',degree=True,cootype='gal')    
plt.plot(ras,decs,'ko')   
#plt.plot(st.ra,st.dec)
plt.xlim(0.,380.)
plt.ylim(-40.,0.)

for raa,deca in zip(ras,decs):
 print '%.1f %+.1f 20. ' % (raa,deca)
# Out:
# 19.0 -23.9 20.
# 19.4 -23.9 20.
# 19.8 -24.0 20.
# 20.2 -24.0 20.
# 20.7 -24.1 20.
# 21.1 -24.2 20.
# 21.5 -24.2 20.
# 21.9 -24.3 20.
# 22.3 -24.4 20.
# 22.7 -24.5 20.
# 23.1 -24.6 20.
# 23.6 -24.7 20.
# 24.0 -24.8 20.
# 24.4 -24.9 20.
# 24.8 -25.1 20.
# 25.2 -25.2 20.
# 25.6 -25.4 20.
# 26.0 -25.6 20.
# 26.4 -25.8 20.
# 26.9 -26.0 20.
# 27.3 -26.2 20.
# 27.7 -26.5 20.
# 28.1 -26.8 20.
# 28.5 -27.1 20.
# 28.9 -27.4 20.
# 29.3 -27.7 20.
# 29.8 -28.1 20.
# 30.2 -28.5 20.
# 30.6 -28.9 20.
# 31.0 -29.3 20.

# %% [markdown]
# ASCII Footprints
# =========================

# %%
streams=galstreams.MWStreams(verbose=False,gcstep=0.05,N=8000)
#Downsize Sgr footprint
print streams['Sgr-L10'].ra.size,
mask=np.arange(streams['Sgr-L10'].ra.size)[::5]
streams['Sgr-L10'].mask_footprint(mask)
print streams['Sgr-L10'].ra.size,
# Out:
# 100000 20000

# %%
#-------------Save footprints in individual files-------------------------
head='#%9s %10s %10s %10s %10s %10s %10s %10s\n' % ('RA_deg','DEC_deg','l_deg','b_deg','Rhel_kpc',
                                                'phi_deg','theta_deg','Rgal_kpc')
for skey in streams.keys():
    #if '/' in skey: skey.replace('/','-')
    ofilen='../../footprints/individual_footprints/galstreams.footprint.%s.dat' % (skey.replace('/','-'))
    print 'Saving footprint for stream',skey,'in',ofilen

    ofile=open(ofilen,'w')
    ofile.write(head)

    Rgal=streams[skey].Rgal
    phi=streams[skey].phi
    theta=streams[skey].theta
    if Rgal is None: Rgal=phi=theta=-1*np.ones_like(streams[skey].l)
    scipy.savetxt(ofile,np.array([streams[skey].ra,streams[skey].dec,
                                   streams[skey].l,streams[skey].b,
                                   streams[skey].Rhel,
                                   phi,theta,Rgal]).T,
                                   fmt='%10.4f %10.4f %10.4f %10.4f %10.3f %10.4f %10.4f %10.3f')
    ofile.close()
# Out:
# Saving footprint for stream Her-Aq in ../../footprints/galstreams.footprint.Her-Aq.dat
# Saving footprint for stream
#  PS1-A in ../../footprints/galstreams.footprint.PS1-A.dat
# Saving footprint for stream Cocytos in ../../footprints/galstreams.footprint.Cocytos.dat
# Saving footprint for stream Acheron in ../../footprints/galstreams.footprint.Acheron.dat
# Saving footprint for stream Hermus in ../../footprints/galstreams.footprint.Hermus.dat
# Saving footprint for stream Sgr-L10 in ../../footprints/galstreams.footprint.Sgr-L10.dat
# Saving footprint for stream
#  ACS in ../../footprints/galstreams.footprint.ACS.dat
# Saving footprint for stream Hyllus in ../../footprints/galstreams.footprint.Hyllus.dat
# Saving footprint for stream ATLAS in ../../footprints/galstreams.footprint.ATLAS.dat
# Saving footprint for stream Tri/Pis in ../../footprints/galstreams.footprint.Tri-Pis.dat
# Saving footprint for stream Murrumbidgee in ../../footprints/galstreams.footprint.Murrumbidgee.dat
# Saving footprint for stream Eridanus in ../../footprints/galstreams.footprint.Eridanus.dat
# Saving footprint for stream Phoenix in ../../footprints/galstreams.footprint.Phoenix.dat
# Saving footprint for stream PiscesOv in ../../footprints/galstreams.footprint.PiscesOv.dat
# Saving footprint for stream
#  PS1-C in ../../footprints/galstreams.footprint.PS1-C.dat
# Saving footprint for stream Lethe in ../../footprints/galstreams.footprint.Lethe.dat
# Saving footprint for stream Pal5 in ../../footprints/galstreams.footprint.Pal5.dat
# Saving footprint for stream PS1-D in ../../footprints/galstreams.footprint.PS1-D.dat
# Saving footprint for stream
#  PS1-E in ../../footprints/galstreams.footprint.PS1-E.dat
# Saving footprint for stream NGC5466 in ../../footprints/galstreams.footprint.NGC5466.dat
# Saving footprint for stream WG4 in ../../footprints/galstreams.footprint.WG4.dat
# Saving footprint for stream WG1 in ../../footprints/galstreams.footprint.WG1.dat
# Saving footprint for stream
#  WG3 in ../../footprints/galstreams.footprint.WG3.dat
# Saving footprint for stream VOD/VSS in ../../footprints/galstreams.footprint.VOD-VSS.dat
# Saving footprint for stream
#  Pal15 in ../../footprints/galstreams.footprint.Pal15.dat
# Saving footprint for stream Kwando in ../../footprints/galstreams.footprint.Kwando.dat
# Saving footprint for stream Scamander in ../../footprints/galstreams.footprint.Scamander.dat
# Saving footprint for stream
#  EriPhe in ../../footprints/galstreams.footprint.EriPhe.dat
# Saving footprint for stream
#  WG2 in ../../footprints/galstreams.footprint.WG2.dat
# Saving footprint for stream Alpheus in ../../footprints/galstreams.footprint.Alpheus.dat
# Saving footprint for stream Tri-And in ../../footprints/galstreams.footprint.Tri-And.dat
# Saving footprint for stream
#  Sangarius in ../../footprints/galstreams.footprint.Sangarius.dat
# Saving footprint for stream
#  Cetus in ../../footprints/galstreams.footprint.Cetus.dat
# Saving footprint for stream Monoceros in ../../footprints/galstreams.footprint.Monoceros.dat
# Saving footprint for stream
#  Styx in ../../footprints/galstreams.footprint.Styx.dat
# Saving footprint for stream Tri-And2 in ../../footprints/galstreams.footprint.Tri-And2.dat
# Saving footprint for stream
#  Ophiucus in ../../footprints/galstreams.footprint.Ophiucus.dat
# Saving footprint for stream GD-1 in ../../footprints/galstreams.footprint.GD-1.dat
# Saving footprint for stream Orinoco in ../../footprints/galstreams.footprint.Orinoco.dat
# Saving footprint for stream PS1-B in ../../footprints/galstreams.footprint.PS1-B.dat
# Saving footprint for stream Molonglo in ../../footprints/galstreams.footprint.Molonglo.dat
# Saving footprint for stream Orphan in ../../footprints/galstreams.footprint.Orphan.dat
# Saving footprint for stream EBS in ../../footprints/galstreams.footprint.EBS.dat
# Saving footprint for stream
#  PAndAS in ../../footprints/galstreams.footprint.PAndAS.dat

# %%
#-------------Save footprints in a single file-------------------------
head='#%9s %10s %10s %10s %10s %10s %10s %10s %4s %6s %-12s\n' % ('RA_deg','DEC_deg','l_deg','b_deg','Rhel_kpc',
                                                'phi_deg','theta_deg','Rgal_kpc',
                                                'NSt','IDst','StreamName')

ofilen='../../footprints/galstreams.footprint.ALL.dat'
ofile=open(ofilen,'w')
ofile.write(head)

olfilen='../../footprints/galstreams.footprint.ALL.reflabels.dat'
olfile=open(olfilen,'w')
olfile.write(head)

snum=0
for skey in streams.keys():
    
    sname=skey
    if '-' in skey: sname=sname.replace('-','')
    if '/' in skey: sname=sname.replace('/','')        
    print 'Saving footprint for stream',skey,'as',sname

    Rgal=streams[skey].Rgal
    phi=streams[skey].phi
    theta=streams[skey].theta
    snum=snum+1 #unique numerical streamID
    
    if Rgal is None: Rgal=phi=theta=-1*np.ones_like(streams[skey].l)
        
    fullnames=['Tri/Pis','VOD/VSS','Sgr-L10','NGC5466','PS1-A','PS1-B','PS1-C','PS1-D','PS1-E',
               'Pal15','Pal5','PAndAS','ATLAS']    
    if skey not in fullnames: shortname=sname[:3]    
    else: shortname=sname
        
    for i in range(streams[skey].ra.size): 
        ofile.write('%10.4f %10.4f %10.4f %10.4f %10.3f %10.4f %10.4f %10.3f %4s %6s %-12s\n' %
                    (streams[skey].ra[i],streams[skey].dec[i],streams[skey].l[i],streams[skey].b[i],
                     streams[skey].Rhel[i],phi[i],theta[i],Rgal[i],snum,shortname,sname))
    
    #one line per stream, to store stream ref point for label    
    olfile.write('%10.4f %10.4f %10.4f %10.4f %10.3f %10.4f %10.4f %10.3f %4s %6s %-12s\n' %
                    (streams[skey].cra,streams[skey].cdec,streams[skey].cl,streams[skey].cb,
                     np.mean(streams[skey].Rhel),phi[0],theta[0],Rgal[0],snum,shortname,sname))
        
        
ofile.close()
olfile.close()
# Out:
# Saving footprint for stream Her-Aq as HerAq
# Saving footprint for stream
#  PS1-A as PS1A
# Saving footprint for stream Cocytos as Cocytos
# Saving footprint for stream Acheron as Acheron
# Saving footprint for stream Hermus as Hermus
# Saving footprint for stream Sgr-L10 as SgrL10
# Saving footprint for stream
#  ACS as ACS
# Saving footprint for stream Hyllus as Hyllus
# Saving footprint for stream ATLAS as ATLAS
# Saving footprint for stream Tri/Pis as TriPis
# Saving footprint for stream Murrumbidgee as Murrumbidgee
# Saving footprint for stream Eridanus as Eridanus
# Saving footprint for stream Phoenix as Phoenix
# Saving footprint for stream PiscesOv as PiscesOv
# Saving footprint for stream
#  PS1-C as PS1C
# Saving footprint for stream Lethe as Lethe
# Saving footprint for stream Pal5 as Pal5
# Saving footprint for stream PS1-D as PS1D
# Saving footprint for stream
#  PS1-E as PS1E
# Saving footprint for stream
#  NGC5466 as NGC5466
# Saving footprint for stream WG4 as WG4
# Saving footprint for stream WG1 as WG1
# Saving footprint for stream WG3 as WG3
# Saving footprint for stream VOD/VSS as VODVSS
# Saving footprint for stream
#  Pal15 as Pal15
# Saving footprint for stream Kwando as Kwando
# Saving footprint for stream Scamander as Scamander
# Saving footprint for stream
#  EriPhe as EriPhe
# Saving footprint for stream
#  WG2 as WG2
# Saving footprint for stream Alpheus as Alpheus
# Saving footprint for stream Tri-And as TriAnd
# Saving footprint for stream
#  Sangarius as Sangarius
# Saving footprint for stream
#  Cetus as Cetus
# Saving footprint for stream Monoceros as Monoceros
# Saving footprint for stream
#  Styx as Styx
# Saving footprint for stream Tri-And2 as TriAnd2
# Saving footprint for stream
#  Ophiucus as Ophiucus
# Saving footprint for stream GD-1 as GD1
# Saving footprint for stream Orinoco as Orinoco
# Saving footprint for stream PS1-B as PS1B
# Saving footprint for stream Molonglo as Molonglo
# Saving footprint for stream Orphan as Orphan
# Saving footprint for stream EBS as EBS
# Saving footprint for stream
#  PAndAS as PAndAS
