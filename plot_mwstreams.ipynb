# %%
import numpy as np
import scipy
import pylab as plt
import mwstreams
import myutils
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
mwsts=mwstreams.MWStreams(verbose=False,gcstep=0.05,N=8000)
nnot=['Hermus','Hyllus','Lethe','Cocytos','Acheron','Alpheus','Scamander','Sangarius']
for i in mwsts.keys():
    if i in nnot : mwsts[i].name=mwsts[i].name[:3]
    if mwsts[i].phi is not None:    
     mwsts[i].phi= (mwsts[i].phi+180.) % 360.
     mwsts[i].cphi= (mwsts[i].cphi+180.) % 360.

# %%
print mwsts['Sgr-L00'].ra.size
mask=np.arange(mwsts['Sgr-L00'].ra.size)[::20]
mwsts['Sgr-L00'].mask_footprint(mask)
mwsts['Sgr-L00'].cphi,mwsts['Sgr-L00'].ctheta=350.,-15.
# Out:
# 100000

# %%
plt.rc('font', size=14)
plt.rc('axes', labelsize=18)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)

fig=plt.figure(1,figsize=(16,8))
ax=fig.add_subplot(111)
my_cmap=myutils.get_sron_rainbow(N=12)
my_cmap.set_under('gray')
ckws=dict(cmap=my_cmap,vmax=50.,vmin=0.)
colorbar_kwargs=dict(pad=0.01,label='Mean $R_{\mathrm{gal}}$ (kpc)',aspect=30.)
mwsts.plot_stream_compilation(ax,scat_kwargs=ckws,verbose=True,plot_colorbar=True,cootype='GC',
                              cb_kwargs=colorbar_kwargs,exclude_streams=['Her-Aq'])#,Rrange=[0.,30.])
ax.grid()
ax.set_xlabel('$\phi$ ($^\circ$)')
ax.set_ylabel('$\\theta$ ($^\circ$)')
ax.set_xlim(0.,360.)
ax.set_ylim(-90,90.)
majorLocator=plt.MultipleLocator(15.)
ax.yaxis.set_major_locator(majorLocator)
plt.savefig('MWStreams_lib.galactocentric.png')
# Out:
# Skipping excluded stream: Her-Aq
# Skipping stream WG4, no valid Rhel => no valid galactocentric attributes
# Skipping stream WG1, no valid Rhel => no valid galactocentric attributes
# Skipping stream WG3, no valid Rhel => no valid galactocentric attributes
# Skipping stream WG2, no valid Rhel => no valid galactocentric attributes

# %%
fig=plt.figure(1,figsize=(16,8))
ax=fig.add_subplot(111)
my_cmap=myutils.get_sron_rainbow(N=12)
my_cmap.set_under('gray')
ckws=dict(cmap=my_cmap,vmax=30.,vmin=0.)
colorbar_kwargs=dict(pad=0.01,label='Mean $R_{\mathrm{hel}}$ (kpc)',aspect=30.)
mwsts.plot_stream_compilation(ax,scat_kwargs=ckws,verbose=True,plot_colorbar=True,cootype='gal',
                              cb_kwargs=colorbar_kwargs,exclude_streams=['Her-Aq'])#,Rrange=[0.,30.])
ax.grid()
ax.set_xlabel('l ($^\circ$)')
ax.set_ylabel('b ($^\circ$)')
ax.set_xlim(0.,360.)
ax.set_ylim(-90,90.)
majorLocator=plt.MultipleLocator(15.)
ax.yaxis.set_major_locator(majorLocator)
plt.savefig('MWStreams_lib.galactic_heliocentric.png')
# Out:
# Skipping excluded stream: Her-Aq

# %%
#Alpheus
dec=np.linspace(-69.,-45.,20)
ra = 32.116-0.00256*dec-0.00225*(dec**2)
for raa,deca in zip(ra,dec):
 print '%.1f %+.1f 2. ' % (raa,deca)
# Out:
# 21.6 -69.0 2.
# 22.0 -67.7 2.
# 22.3 -66.5 2.
# 22.7 -65.2 2.
# 23.1 -63.9 2.
# 23.4 -62.7 2.
# 23.8 -61.4 2.
# 24.1 -60.2 2.
# 24.5 -58.9 2.
# 24.8 -57.6 2.
# 25.1 -56.4 2.
# 25.4 -55.1 2.
# 25.7 -53.8 2.
# 26.0 -52.6 2.
# 26.3 -51.3 2.
# 26.6 -50.1 2.
# 26.9 -48.8 2.
# 27.2 -47.5 2.
# 27.4 -46.3 2.
# 27.7 -45.0 2.

# %%
#Hermus
dec=np.linspace(5.,+50.,200)
ra=241.571 + 1.37841*dec -0.148870*(dec**2) + 0.00589502*(dec**3) -1.03927E-4*(dec**4) + 7.28133E-7*(dec**5)
for raa,deca in zip(ra,dec):
 print '%.1f %+6.1f 18.5 ' % (raa,deca)
# Out:
# 245.4   +5.0 18.5
# 245.5   +5.2 18.5
# 245.5   +5.5 18.5
# 245.6   +5.7 18.5
# 245.6   +5.9 18.5
# 245.6   +6.1 18.5
# 245.7   +6.4 18.5
# 245.7   +6.6 18.5
# 245.7   +6.8 18.5
# 245.7   +7.0 18.5
# 245.7   +7.3 18.5
# 245.7   +7.5 18.5
# 245.7   +7.7 18.5
# 245.7   +7.9 18.5
# 245.7   +8.2 18.5
# 245.7   +8.4 18.5
# 245.6   +8.6 18.5
# 245.6   +8.8 18.5
# 245.6   +9.1 18.5
# 245.5   +9.3 18.5
# 245.5   +9.5 18.5
# 245.4   +9.7 18.5
# 245.4  +10.0 18.5
# 245.4  +10.2 18.5
# 245.3  +10.4 18.5
# 245.2  +10.7 18.5
# 245.2  +10.9 18.5
# 245.1  +11.1 18.5
# 245.1  +11.3 18.5
# 245.0  +11.6 18.5
# 244.9  +11.8 18.5
# 244.9  +12.0 18.5
# 244.8  +12.2 18.5
# 244.8  +12.5 18.5
# 244.7  +12.7 18.5
# 244.6  +12.9 18.5
# 244.5  +13.1 18.5
# 244.5  +13.4 18.5
# 244.4  +13.6 18.5
# 244.3  +13.8 18.5
# 244.3  +14.0 18.5
# 244.2  +14.3 18.5
# 244.1  +14.5 18.5
# 244.0  +14.7 18.5
# 244.0  +14.9 18.5
# 243.9  +15.2 18.5
# 243.8  +15.4 18.5
# 243.7  +15.6 18.5
# 243.7  +15.9 18.5
# 243.6  +16.1 18.5
# 243.5  +16.3 18.5
# 243.4  +16.5 18.5
# 243.4  +16.8 18.5
# 243.3  +17.0 18.5
# 243.2  +17.2 18.5
# 243.2  +17.4 18.5
# 243.1  +17.7 18.5
# 243.0  +17.9 18.5
# 243.0  +18.1 18.5
# 242.9  +18.3 18.5
# 242.8  +18.6 18.5
# 242.8  +18.8 18.5
# 242.7  +19.0 18.5
# 242.6  +19.2 18.5
# 242.6  +19.5 18.5
# 242.5  +19.7 18.5
# 242.5  +19.9 18.5
# 242.4  +20.2 18.5
# 242.4  +20.4 18.5
# 242.3  +20.6 18.5
# 242.3  +20.8 18.5
# 242.2  +21.1 18.5
# 242.2  +21.3 18.5
# 242.1  +21.5 18.5
# 242.1  +21.7 18.5
# 242.0  +22.0 18.5
# 242.0  +22.2 18.5
# 241.9  +22.4 18.5
# 241.9  +22.6 18.5
# 241.9  +22.9 18.5
# 241.8  +23.1 18.5
# 241.8  +23.3 18.5
# 241.8  +23.5 18.5
# 241.7  +23.8 18.5
# 241.7  +24.0 18.5
# 241.7  +24.2 18.5
# 241.7  +24.4 18.5
# 241.6  +24.7 18.5
# 241.6  +24.9 18.5
# 241.6  +25.1 18.5
# 241.6  +25.4 18.5
# 241.6  +25.6 18.5
# 241.6  +25.8 18.5
# 241.5  +26.0 18.5
# 241.5  +26.3 18.5
# 241.5  +26.5 18.5
# 241.5  +26.7 18.5
# 241.5  +26.9 18.5
# 241.5  +27.2 18.5
# 241.5  +27.4 18.5
# 241.5  +27.6 18.5
# 241.5  +27.8 18.5
# 241.5  +28.1 18.5
# 241.5  +28.3 18.5
# 241.5  +28.5 18.5
# 241.5  +28.7 18.5
# 241.5  +29.0 18.5
# 241.6  +29.2 18.5
# 241.6  +29.4 18.5
# 241.6  +29.6 18.5
# 241.6  +29.9 18.5
# 241.6  +30.1 18.5
# 241.6  +30.3 18.5
# 241.7  +30.6 18.5
# 241.7  +30.8 18.5
# 241.7  +31.0 18.5
# 241.8  +31.2 18.5
# 241.8  +31.5 18.5
# 241.8  +31.7 18.5
# 241.8  +31.9 18.5
# 241.9  +32.1 18.5
# 241.9  +32.4 18.5
# 242.0  +32.6 18.5
# 242.0  +32.8 18.5
# 242.0  +33.0 18.5
# 242.1  +33.3 18.5
# 242.1  +33.5 18.5
# 242.2  +33.7 18.5
# 242.2  +33.9 18.5
# 242.3  +34.2 18.5
# 242.3  +34.4 18.5
# 242.4  +34.6 18.5
# 242.4  +34.8 18.5
# 242.5  +35.1 18.5
# 242.6  +35.3 18.5
# 242.6  +35.5 18.5
# 242.7  +35.8 18.5
# 242.8  +36.0 18.5
# 242.8  +36.2 18.5
# 242.9  +36.4 18.5
# 243.0  +36.7 18.5
# 243.0  +36.9 18.5
# 243.1  +37.1 18.5
# 243.2  +37.3 18.5
# 243.3  +37.6 18.5
# 243.4  +37.8 18.5
# 243.5  +38.0 18.5
# 243.5  +38.2 18.5
# 243.6  +38.5 18.5
# 243.7  +38.7 18.5
# 243.8  +38.9 18.5
# 243.9  +39.1 18.5
# 244.0  +39.4 18.5
# 244.1  +39.6 18.5
# 244.2  +39.8 18.5
# 244.3  +40.1 18.5
# 244.4  +40.3 18.5
# 244.6  +40.5 18.5
# 244.7  +40.7 18.5
# 244.8  +41.0 18.5
# 244.9  +41.2 18.5
# 245.0  +41.4 18.5
# 245.2  +41.6 18.5
# 245.3  +41.9 18.5
# 245.4  +42.1 18.5
# 245.6  +42.3 18.5
# 245.7  +42.5 18.5
# 245.9  +42.8 18.5
# 246.0  +43.0 18.5
# 246.2  +43.2 18.5
# 246.3  +43.4 18.5
# 246.5  +43.7 18.5
# 246.6  +43.9 18.5
# 246.8  +44.1 18.5
# 247.0  +44.3 18.5
# 247.2  +44.6 18.5
# 247.3  +44.8 18.5
# 247.5  +45.0 18.5
# 247.7  +45.3 18.5
# 247.9  +45.5 18.5
# 248.1  +45.7 18.5
# 248.3  +45.9 18.5
# 248.6  +46.2 18.5
# 248.8  +46.4 18.5
# 249.0  +46.6 18.5
# 249.2  +46.8 18.5
# 249.5  +47.1 18.5
# 249.7  +47.3 18.5
# 250.0  +47.5 18.5
# 250.2  +47.7 18.5
# 250.5  +48.0 18.5
# 250.8  +48.2 18.5
# 251.0  +48.4 18.5
# 251.3  +48.6 18.5
# 251.6  +48.9 18.5
# 251.9  +49.1 18.5
# 252.2  +49.3 18.5
# 252.5  +49.5 18.5
# 252.9  +49.8 18.5
# 253.2  +50.0 18.5

# %%
#Hyllus
dec=np.linspace(11.,+34.,200)
ra=255.8150-0.78364*dec + 0.01532*dec**2
for raa,deca in zip(ra,dec):
 print '%.1f %+.1f 20. ' % (raa,deca)
# Out:
# 249.0 +11.0 20.
# 249.0 +11.1 20.
# 248.9 +11.2 20.
# 248.9 +11.3 20.
# 248.8 +11.5 20.
# 248.8 +11.6 20.
# 248.7 +11.7 20.
# 248.7 +11.8 20.
# 248.6 +11.9 20.
# 248.6 +12.0 20.
# 248.6 +12.2 20.
# 248.5 +12.3 20.
# 248.5 +12.4 20.
# 248.4 +12.5 20.
# 248.4 +12.6 20.
# 248.3 +12.7 20.
# 248.3 +12.8 20.
# 248.2 +13.0 20.
# 248.2 +13.1 20.
# 248.1 +13.2 20.
# 248.1 +13.3 20.
# 248.1 +13.4 20.
# 248.0 +13.5 20.
# 248.0 +13.7 20.
# 247.9 +13.8 20.
# 247.9 +13.9 20.
# 247.8 +14.0 20.
# 247.8 +14.1 20.
# 247.8 +14.2 20.
# 247.7 +14.4 20.
# 247.7 +14.5 20.
# 247.6 +14.6 20.
# 247.6 +14.7 20.
# 247.6 +14.8 20.
# 247.5 +14.9 20.
# 247.5 +15.0 20.
# 247.5 +15.2 20.
# 247.4 +15.3 20.
# 247.4 +15.4 20.
# 247.3 +15.5 20.
# 247.3 +15.6 20.
# 247.3 +15.7 20.
# 247.2 +15.9 20.
# 247.2 +16.0 20.
# 247.2 +16.1 20.
# 247.1 +16.2 20.
# 247.1 +16.3 20.
# 247.1 +16.4 20.
# 247.0 +16.5 20.
# 247.0 +16.7 20.
# 247.0 +16.8 20.
# 246.9 +16.9 20.
# 246.9 +17.0 20.
# 246.9 +17.1 20.
# 246.9 +17.2 20.
# 246.8 +17.4 20.
# 246.8 +17.5 20.
# 246.8 +17.6 20.
# 246.7 +17.7 20.
# 246.7 +17.8 20.
# 246.7 +17.9 20.
# 246.7 +18.1 20.
# 246.6 +18.2 20.
# 246.6 +18.3 20.
# 246.6 +18.4 20.
# 246.6 +18.5 20.
# 246.5 +18.6 20.
# 246.5 +18.7 20.
# 246.5 +18.9 20.
# 246.5 +19.0 20.
# 246.4 +19.1 20.
# 246.4 +19.2 20.
# 246.4 +19.3 20.
# 246.4 +19.4 20.
# 246.3 +19.6 20.
# 246.3 +19.7 20.
# 246.3 +19.8 20.
# 246.3 +19.9 20.
# 246.3 +20.0 20.
# 246.2 +20.1 20.
# 246.2 +20.2 20.
# 246.2 +20.4 20.
# 246.2 +20.5 20.
# 246.2 +20.6 20.
# 246.2 +20.7 20.
# 246.1 +20.8 20.
# 246.1 +20.9 20.
# 246.1 +21.1 20.
# 246.1 +21.2 20.
# 246.1 +21.3 20.
# 246.1 +21.4 20.
# 246.0 +21.5 20.
# 246.0 +21.6 20.
# 246.0 +21.7 20.
# 246.0 +21.9 20.
# 246.0 +22.0 20.
# 246.0 +22.1 20.
# 246.0 +22.2 20.
# 246.0 +22.3 20.
# 245.9 +22.4 20.
# 245.9 +22.6 20.
# 245.9 +22.7 20.
# 245.9 +22.8 20.
# 245.9 +22.9 20.
# 245.9 +23.0 20.
# 245.9 +23.1 20.
# 245.9 +23.3 20.
# 245.9 +23.4 20.
# 245.9 +23.5 20.
# 245.9 +23.6 20.
# 245.8 +23.7 20.
# 245.8 +23.8 20.
# 245.8 +23.9 20.
# 245.8 +24.1 20.
# 245.8 +24.2 20.
# 245.8 +24.3 20.
# 245.8 +24.4 20.
# 245.8 +24.5 20.
# 245.8 +24.6 20.
# 245.8 +24.8 20.
# 245.8 +24.9 20.
# 245.8 +25.0 20.
# 245.8 +25.1 20.
# 245.8 +25.2 20.
# 245.8 +25.3 20.
# 245.8 +25.4 20.
# 245.8 +25.6 20.
# 245.8 +25.7 20.
# 245.8 +25.8 20.
# 245.8 +25.9 20.
# 245.8 +26.0 20.
# 245.8 +26.1 20.
# 245.8 +26.3 20.
# 245.8 +26.4 20.
# 245.8 +26.5 20.
# 245.8 +26.6 20.
# 245.8 +26.7 20.
# 245.8 +26.8 20.
# 245.8 +26.9 20.
# 245.8 +27.1 20.
# 245.8 +27.2 20.
# 245.8 +27.3 20.
# 245.8 +27.4 20.
# 245.9 +27.5 20.
# 245.9 +27.6 20.
# 245.9 +27.8 20.
# 245.9 +27.9 20.
# 245.9 +28.0 20.
# 245.9 +28.1 20.
# 245.9 +28.2 20.
# 245.9 +28.3 20.
# 245.9 +28.5 20.
# 245.9 +28.6 20.
# 245.9 +28.7 20.
# 246.0 +28.8 20.
# 246.0 +28.9 20.
# 246.0 +29.0 20.
# 246.0 +29.1 20.
# 246.0 +29.3 20.
# 246.0 +29.4 20.
# 246.0 +29.5 20.
# 246.0 +29.6 20.
# 246.1 +29.7 20.
# 246.1 +29.8 20.
# 246.1 +30.0 20.
# 246.1 +30.1 20.
# 246.1 +30.2 20.
# 246.1 +30.3 20.
# 246.2 +30.4 20.
# 246.2 +30.5 20.
# 246.2 +30.6 20.
# 246.2 +30.8 20.
# 246.2 +30.9 20.
# 246.2 +31.0 20.
# 246.3 +31.1 20.
# 246.3 +31.2 20.
# 246.3 +31.3 20.
# 246.3 +31.5 20.
# 246.3 +31.6 20.
# 246.4 +31.7 20.
# 246.4 +31.8 20.
# 246.4 +31.9 20.
# 246.4 +32.0 20.
# 246.5 +32.2 20.
# 246.5 +32.3 20.
# 246.5 +32.4 20.
# 246.5 +32.5 20.
# 246.6 +32.6 20.
# 246.6 +32.7 20.
# 246.6 +32.8 20.
# 246.6 +33.0 20.
# 246.7 +33.1 20.
# 246.7 +33.2 20.
# 246.7 +33.3 20.
# 246.7 +33.4 20.
# 246.8 +33.5 20.
# 246.8 +33.7 20.
# 246.8 +33.8 20.
# 246.9 +33.9 20.
# 246.9 +34.0 20.

# %%
#Sangarius
ra=148.9492-0.03811*dec+0.001505*dec**2
#Scamander
ra=155.642-0.1000*dec-0.00191*dec**2-0.0003346*dec**3+1.47775E-5*dec**4

# %%
#Orphan extension, Grillmair
orphan_ext_delta=np.linspace(-18.,-38.,4)
orphan_ext_alpha=163.147-0.0896*orphan_ext_delta+0.00804*(orphan_ext_delta**2)
orph_l,orph_b=bovyc.radec_to_lb(orphan_ext_alpha,orphan_ext_delta,degree=True).T
for la,ba in zip(orph_l,orph_b):
 print '%.1f %+.1f -1. ' % (la,ba)
# Out:
# 271.4 +38.5 -1.
# 278.1 +33.8 -1.
# 284.4 +28.8 -1.
# 290.3 +23.4 -1.

# %%
mwsts2=mwstreams.MWStreams(verbose=True)
# Out:
# Reading lon-lat range for VOD/VSS
# Reading lon-lat range for Monoceros
# Reading lon-lat range for NGC5466
# Reading lon-lat range for ACS
# Reading lon-lat range for EBS
# Reading lon-lat range for Her-Aq
# Reading lon-lat range for PAndAS
# Reading lon-lat range for Tri-And
# Reading lon-lat range for Tri-And2
# Reading lon-lat range for PiscesOv
# Reading pair-list for Phoenix
# Reading pair-list for WG1
# Reading pair-list for WG2
# Reading pair-list for WG3
# Reading pair-list for WG4
# Reading pair-list for Acheron
# Reading pair-list for Cocytos
# Reading pair-list for Lethe
# Reading pair-list for Styx
# Reading pair-list for Pal5
# Reading pair-list for GD-1
# Reading pair-list for ACS
# Reading pole-list for PS1-A
#  computed center [29.259489144240376, -4.2394063197825131]
# Reading pole-list for PS1-B
#  computed center [148.31100780172466, -11.125339942796156]
# Reading pole-list for PS1-C
#  computed center [332.61445643977447, 14.942563260633518]
# Reading pole-list for PS1-D
#  computed center [139.85727505224017, 0.83234554085025214]
# Reading pole-list for PS1-E
#  computed center [173.33650214603963, 55.390553459394773]
# Reading pole-list for ATLAS
#  same system, center: [25.0, -30.0]
# Reading pole-list for Ophiucus
#  computed center [241.79677272166143, -6.9308569865551624]
# Reading pole-list for Sangarius
#  computed center [229.50606912074244, 44.272405559601367]
# Reading pole-list for Scamander
#  computed center [226.75769309327029, 50.397913733665469]
# Reading star list for Sgr-L00
# Reading star list for Orphan
# Reading star list for Tri/Pis
# Reading star list for NGC5466
# Reading star list for Alpheus
# Reading star list for Hermus
# Reading star list for Hyllus
# Reading star list for Cetus

# %%
ax=plt.subplot(111)
mwsts2.plot_stream_compilation(ax,verbose=True,plot_colorbar=True)#,Rrange=[0.,30.])
